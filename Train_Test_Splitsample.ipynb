# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv('wines_SPA.csv')

# %%
df = df.dropna()

# %%
df
# Out:
#                     winery             wine  year  rating  num_reviews  \
# 0            Teso La Monja            Tinto  2013     4.9           58
# 1                   Artadi    Vina El Pison  2018     4.9           31
# 2             Vega Sicilia            Unico  2009     4.8         1793
# 3             Vega Sicilia            Unico  1999     4.8         1705
# 4             Vega Sicilia            Unico  1996     4.8         1309
# ...                    ...              ...   ...     ...          ...
# 7495               Contino          Reserva  2016     4.2          392
# 7496  Conreria d'Scala Dei    Les Brugueres  2018     4.2          390
# 7497           Mustiguillo  Finca Terrerazo  2017     4.2          390
# 7498           Matarromera     Gran Reserva  2011     4.2          389
# 7499              Sei Solo         Preludio  2016     4.2          388
#
#      country            region   price                  type  body  acidity
# 0     Espana              Toro  995.00              Toro Red   5.0      3.0
# 1     Espana    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2     Espana  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3     Espana  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4     Espana  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0
# ...      ...               ...     ...                   ...   ...      ...
# 7495  Espana             Rioja   19.98             Rioja Red   4.0      3.0
# 7496  Espana          Priorato   16.76           Priorat Red   4.0      3.0
# 7497  Espana      El Terrerazo   24.45                   Red   4.0      3.0
# 7498  Espana  Ribera del Duero   64.50  Ribera Del Duero Red   5.0      3.0
# 7499  Espana  Ribera del Duero   31.63  Ribera Del Duero Red   5.0      3.0
#
# [6329 rows x 11 columns]

# %% [markdown]
# ### Implement Train Test Split Manually

# %%
df = df.sample(frac = 1)

df
# Out:
#                 winery                                wine  year  rating  \
# 131       Clos Erasmus                             Priorat  2007     4.7
# 4917            Artadi                          Valdegines  2016     4.2
# 3073          Sei Solo                            Preludio  2016     4.2
# 831               Jaro                           Chafandin  2018     4.4
# 3477         Clos Pons                              Roc Nu  2011     4.2
# ...                ...                                 ...   ...     ...
# 6542             Matsu                            El Viejo  2019     4.2
# 393   Bodega Numanthia                          Termanthia  2010     4.5
# 3287            Lustau           Candela Cream Dulce Sweet  N.V.     4.2
# 4456     Mar de Frades  Rias Baixas Albarino Finca Valinas  2015     4.2
# 410            Arzuaga            Reserva Ribera del Duero  2017     4.5
#
#       num_reviews country              region   price                  type  \
# 131            60  Espana            Priorato  654.31           Priorat Red
# 4917          398  Espana      Vino de Espana   48.96           Tempranillo
# 3073          388  Espana    Ribera del Duero   31.63  Ribera Del Duero Red
# 831           155  Espana    Ribera del Duero   28.95  Ribera Del Duero Red
# 3477          420  Espana   Costers del Segre   23.95                   Red
# ...           ...     ...                 ...     ...                   ...
# 6542          400  Espana                Toro   27.89              Toro Red
# 393           729  Espana                Toro  168.00              Toro Red
# 3287          405  Espana  Jerez-Xeres-Sherry    7.10                Sherry
# 4456          414  Espana         Rias Baixas   16.78              Albarino
# 410           477  Espana    Ribera del Duero   31.80  Ribera Del Duero Red
#
#       body  acidity
# 131    4.0      3.0
# 4917   4.0      2.0
# 3073   5.0      3.0
# 831    5.0      3.0
# 3477   4.0      3.0
# ...    ...      ...
# 6542   5.0      3.0
# 393    5.0      3.0
# 3287   4.0      3.0
# 4456   3.0      3.0
# 410    5.0      3.0
#
# [6329 rows x 11 columns]

# %%
features = df.drop(columns = ['price'])
target = df['price']

# %%
def train_test_split(data, test_size=0.2):
  len_data = len(data)
  test_index = int(len_data * test_size)
  X_test = features[:test_index]
  y_test = target[:test_index]
  X_train = features[test_index:]
  y_train = target[test_index:]
  return X_train, y_train, X_test, y_test

# %%
X_train, y_train, X_test, y_test = train_test_split(df)
X_train
# Out:
#                 winery                                wine  year  rating  \
# 1288        Vall Llach                  Porrera Vi de Vila  2012     4.3
# 7293            Artadi                          Valdegines  2016     4.2
# 5140      Ramon Bilbao                               Mirto  2011     4.2
# 3006     Mar de Frades  Rias Baixas Albarino Finca Valinas  2015     4.2
# 7470           Contino                             Reserva  2016     4.2
# ...                ...                                 ...   ...     ...
# 6542             Matsu                            El Viejo  2019     4.2
# 393   Bodega Numanthia                          Termanthia  2010     4.5
# 3287            Lustau           Candela Cream Dulce Sweet  N.V.     4.2
# 4456     Mar de Frades  Rias Baixas Albarino Finca Valinas  2015     4.2
# 410            Arzuaga            Reserva Ribera del Duero  2017     4.5
#
#       num_reviews country              region                  type  body  \
# 1288          364  Espana            Priorato           Priorat Red   4.0
# 7293          398  Espana      Vino de Espana           Tempranillo   4.0
# 5140          402  Espana               Rioja             Rioja Red   4.0
# 3006          414  Espana         Rias Baixas              Albarino   3.0
# 7470          392  Espana               Rioja             Rioja Red   4.0
# ...           ...     ...                 ...                   ...   ...
# 6542          400  Espana                Toro              Toro Red   5.0
# 393           729  Espana                Toro              Toro Red   5.0
# 3287          405  Espana  Jerez-Xeres-Sherry                Sherry   4.0
# 4456          414  Espana         Rias Baixas              Albarino   3.0
# 410           477  Espana    Ribera del Duero  Ribera Del Duero Red   5.0
#
#       acidity
# 1288      3.0
# 7293      2.0
# 5140      3.0
# 3006      3.0
# 7470      3.0
# ...       ...
# 6542      3.0
# 393       3.0
# 3287      3.0
# 4456      3.0
# 410       3.0
#
# [5064 rows x 10 columns]

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (5064, 10) (1265, 10) (5064,) (1265,)
