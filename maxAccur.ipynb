# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
# Out:
# /var/folders/3c/pb1mvv954893vlh3_4cdhtww0000gn/T/ipykernel_78069/1112673610.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv('wines_SPA.csv')

# %%
df.head()
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
# 2   Vega Sicilia          Unico  2009     4.8         1793  Espana
# 3   Vega Sicilia          Unico  1999     4.8         1705  Espana
# 4   Vega Sicilia          Unico  1996     4.8         1309  Espana
#
#              region   price                  type  body  acidity
# 0              Toro  995.00              Toro Red   5.0      3.0
# 1    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0

# %%
df.sample(5)
# Out:
#                     winery                                wine  year  rating  \
# 7482         Mar de Frades  Rias Baixas Albarino Finca Valinas  2015     4.2
# 6941          Ramon Bilbao                               Mirto  2011     4.2
# 5324    Vinedos de Paganos                          El Puntido  2005     4.2
# 5017                Artadi                          Valdegines  2016     4.2
# 4345  Conreria d'Scala Dei                       Les Brugueres  2018     4.2
#
#       num_reviews country          region  price         type  body  acidity
# 7482          414  Espana     Rias Baixas  16.78     Albarino   3.0      3.0
# 6941          402  Espana           Rioja  28.53    Rioja Red   4.0      3.0
# 5324          384  Espana           Rioja  73.00    Rioja Red   4.0      3.0
# 5017          398  Espana  Vino de Espana  48.96  Tempranillo   4.0      2.0
# 4345          390  Espana        Priorato  16.76  Priorat Red   4.0      3.0

# %%
df.isnull().sum()
# Out:
# winery            0
# wine              0
# year              2
# rating            0
# num_reviews       0
# country           0
# region            0
# price             0
# type            545
# body           1169
# acidity        1169
# dtype: int64

# %%
df['body']=df.body.fillna(df.body.mean())

# %%
df['acidity']=df.acidity.fillna(df.acidity.mean())

# %%
X =df.drop(columns=['price'],axis=1)

y=df['price']
X.dtypes
# Out:
# winery          object
# wine            object
# year            object
# rating         float64
# num_reviews      int64
# country         object
# region          object
# type            object
# body           float64
# acidity        float64
# dtype: object

# %%
# from sklearn.preprocessing import 
# from sklearn.compose import ColumnTransformer

# categorical_features=['wine']

# one_hot=OneHotEncoder()

# transformer=ColumnTransformer([("one_hot",one_hot,categorical_features)],remainder="passthrough")

# Tranformed_X=transformer.fit_transform(X)

# Tranformed_X

# Tranformed_X

# pd.DataFrame(Tranformed_X)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X['country']= le.fit_transform(X['country'])
X['region']= le.fit_transform(X['region'])
X['winery']= le.fit_transform(X['wine'])
X['wine']= le.fit_transform(X['wine'])
X['type']= le.fit_transform(X['type'])
X['year']= le.fit_transform(X['year'])
X.dtypes
# Out:
# winery         int64
# wine           int64
# year           int64
# rating         int64
# num_reviews    int64
# country        int64
# region         int64
# type           int64
# body           int64
# acidity        int64
# dtype: object

# %%
X['body'] = X['body'].astype('int64')
X['acidity'] = X['acidity'].astype('int64')
X['rating'] = X['rating'].astype('int64')
X.dtypes
# Out:
# winery         int64
# wine           int64
# year           int64
# rating         int64
# num_reviews    int64
# country        int64
# region         int64
# type           int64
# body           int64
# acidity        int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.2, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# X_train = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
classifier = svm.SVC(kernel='linear')

# %%
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
X_train_prediction = classifier.predict(X_train)
training_data_accuray = accuracy_score(X_train_prediction,Y_train)
print('Accuracy on training data : ', training_data_accuray)
# Out:
# Accuracy on training data :  0.749

# %%
from sklearn.linear_model import LogisticRegression

# Logistic Regression Model
logistic_classifier = LogisticRegression()
logistic_classifier.fit(X_train, Y_train)

# Model Evaluation
logistic_train_predictions = logistic_classifier.predict(X_train)
logistic_train_accuracy = accuracy_score(logistic_train_predictions, Y_train)

print('Logistic Regression Accuracy on training data:', logistic_train_accuracy)

logistic_test_predictions = logistic_classifier.predict(X_test)
logistic_test_accuracy = accuracy_score(logistic_test_predictions, Y_test)

print('Logistic Regression Accuracy on test data:', logistic_test_accuracy)
# Out:
# Logistic Regression Accuracy on training data: 0.698
# Logistic Regression Accuracy on test data: 0.7066666666666667
# /Users/sagilinithin/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.tree import DecisionTreeClassifier

# Decision Tree Model
dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train, Y_train)

# Model Evaluation
dt_train_predictions = dt_classifier.predict(X_train)
dt_train_accuracy = accuracy_score(dt_train_predictions, Y_train)

print('Decision Tree Accuracy on training data:', dt_train_accuracy)

dt_test_predictions = dt_classifier.predict(X_test)
dt_test_accuracy = accuracy_score(dt_test_predictions, Y_test)

print('Decision Tree Accuracy on test data:', dt_test_accuracy)
# Out:
# Decision Tree Accuracy on training data: 1.0
# Decision Tree Accuracy on test data: 0.758

# %%
from sklearn.ensemble import RandomForestClassifier

# Random Forest Model
rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, Y_train)

# Model Evaluation
rf_train_predictions = rf_classifier.predict(X_train)
rf_train_accuracy = accuracy_score(rf_train_predictions, Y_train)

print('Random Forest Accuracy on training data:', rf_train_accuracy)

rf_test_predictions = rf_classifier.predict(X_test)
rf_test_accuracy = accuracy_score(rf_test_predictions, Y_test)

print('Random Forest Accuracy on test data:', rf_test_accuracy)
# Out:
# Random Forest Accuracy on training data: 1.0
# Random Forest Accuracy on test data: 0.76

# %%
from sklearn.neighbors import KNeighborsClassifier

# KNN Model
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train, Y_train)

# Model Evaluation
knn_train_predictions = knn_classifier.predict(X_train)
knn_train_accuracy = accuracy_score(knn_train_predictions, Y_train)

print('KNN Accuracy on training data:', knn_train_accuracy)

knn_test_predictions = knn_classifier.predict(X_test)
knn_test_accuracy = accuracy_score(knn_test_predictions, Y_test)

print('KNN Accuracy on test data:', knn_test_accuracy)
# Out:
# KNN Accuracy on training data: 0.7865
# KNN Accuracy on test data: 0.7553333333333333

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

# Load the Diabetes dataset
data = load_diabetes()

# Initialize Gradient Boosting Regressor
gb_regressor = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Train the model
gb_regressor.fit(X_train, Y_train)

# Make predictions
y_pred = gb_regressor.predict(X_test)
gb_accuracy=accuracy_score(y_pred,Y_test)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/sagilinithin/Regression/maxAccur.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/Users/sagilinithin/Regression/maxAccur.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.datasets import load_boston
#       <a href='vscode-notebook-cell:/Users/sagilinithin/Regression/maxAccur.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> from sklearn.model_selection import train_test_split
#       <a href='vscode-notebook-cell:/Users/sagilinithin/Regression/maxAccur.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> from sklearn.ensemble import GradientBoostingRegressor
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/datasets/__init__.py:157, in __getattr__(name)
#     108 if name == "load_boston":
#     109     msg = textwrap.dedent("""
#     110         `load_boston` has been removed from scikit-learn since version 1.2.
#     111
# ...
